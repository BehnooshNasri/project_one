# %%
#importing dependencies
import pandas as pd
import requests
from pprint import pprint

# %%
world_master_1_df = pd.read_csv("../downloads/Masters_enrollment.csv")
world_master_1_df.head()
# Out:
#                                          Series Name        Series Code  \
# 0  Educational attainment, at least Master's or e...  SE.TER.CUAT.MS.ZS
# 1  Educational attainment, at least Master's or e...  SE.TER.CUAT.MS.ZS
# 2  Educational attainment, at least Master's or e...  SE.TER.CUAT.MS.ZS
# 3  Educational attainment, at least Master's or e...  SE.TER.CUAT.MS.ZS
# 4  Educational attainment, at least Master's or e...  SE.TER.CUAT.MS.ZS
#
#      Country Name Country Code 2020
# 0     Afghanistan          AFG    ..
# 1         Albania          ALB    ..
# 2         Algeria          DZA    ..
# 3  American Samoa          ASM    ..
# 4         Andorra          AND    ..

# %%
world_master_1_df = world_master_1_df.drop(columns = "Series Code")
world_master_1_df
# Out:
#                                            Series Name           Country Name  \
# 0    Educational attainment, at least Master's or e...            Afghanistan
# 1    Educational attainment, at least Master's or e...                Albania
# 2    Educational attainment, at least Master's or e...                Algeria
# 3    Educational attainment, at least Master's or e...         American Samoa
# 4    Educational attainment, at least Master's or e...                Andorra
# ..                                                 ...                    ...
# 212  Educational attainment, at least Master's or e...  Virgin Islands (U.S.)
# 213  Educational attainment, at least Master's or e...     West Bank and Gaza
# 214  Educational attainment, at least Master's or e...            Yemen, Rep.
# 215  Educational attainment, at least Master's or e...                 Zambia
# 216  Educational attainment, at least Master's or e...               Zimbabwe
#
#     Country Code            2020
# 0            AFG               ..
# 1            ALB               ..
# 2            DZA               ..
# 3            ASM               ..
# 4            AND               ..
# ..           ...              ...
# 212          VIR               ..
# 213          PSE  1.9466700553894
# 214          YEM               ..
# 215          ZMB               ..
# 216          ZWE               ..
#
# [217 rows x 4 columns]

# %%
world_doctorate_df = pd.read_csv("../downloads/Doctorate_enrollment.csv")
world_doctorate_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 world_doctorate_df = pd.read_csv("../downloads/Doctorate_enrollment.csv")
#       2 world_doctorate_df.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../downloads/Doctorate_enrollment.csv'

# %%
world_doctorate_df = world_doctorate_df.drop(columns = "Series Code")
world_doctorate_df
# Out:
#               Country Name Country Code  \
# 0              Afghanistan          AFG
# 1                  Albania          ALB
# 2                  Algeria          DZA
# 3           American Samoa          ASM
# 4                  Andorra          AND
# ..                     ...          ...
# 212  Virgin Islands (U.S.)          VIR
# 213     West Bank and Gaza          PSE
# 214            Yemen, Rep.          YEM
# 215                 Zambia          ZMB
# 216               Zimbabwe          ZWE
#
#                                            Series Name               2020
# 0    Educational attainment, Doctoral or equivalent...                 ..
# 1    Educational attainment, Doctoral or equivalent...                 ..
# 2    Educational attainment, Doctoral or equivalent...                 ..
# 3    Educational attainment, Doctoral or equivalent...                 ..
# 4    Educational attainment, Doctoral or equivalent...                 ..
# ..                                                 ...                ...
# 212  Educational attainment, Doctoral or equivalent...                 ..
# 213  Educational attainment, Doctoral or equivalent...  0.269989997148514
# 214  Educational attainment, Doctoral or equivalent...                 ..
# 215  Educational attainment, Doctoral or equivalent...                 ..
# 216  Educational attainment, Doctoral or equivalent...                 ..
#
# [217 rows x 4 columns]

# %%
merged_df = pd.merge(world_master_1_df, world_doctorate_df, on='Country Name', how='inner')
merged_df
# Out:
#                                          Series Name_x           Country Name  \
# 0    Educational attainment, at least Master's or e...            Afghanistan
# 1    Educational attainment, at least Master's or e...                Albania
# 2    Educational attainment, at least Master's or e...                Algeria
# 3    Educational attainment, at least Master's or e...         American Samoa
# 4    Educational attainment, at least Master's or e...                Andorra
# ..                                                 ...                    ...
# 212  Educational attainment, at least Master's or e...  Virgin Islands (U.S.)
# 213  Educational attainment, at least Master's or e...     West Bank and Gaza
# 214  Educational attainment, at least Master's or e...            Yemen, Rep.
# 215  Educational attainment, at least Master's or e...                 Zambia
# 216  Educational attainment, at least Master's or e...               Zimbabwe
#
#     Country Code_x            2020  Country Code_y  \
# 0              AFG               ..            AFG
# 1              ALB               ..            ALB
# 2              DZA               ..            DZA
# 3              ASM               ..            ASM
# 4              AND               ..            AND
# ..             ...              ...            ...
# 212            VIR               ..            VIR
# 213            PSE  1.9466700553894            PSE
# 214            YEM               ..            YEM
# 215            ZMB               ..            ZMB
# 216            ZWE               ..            ZWE
#
#                                          Series Name_y               2020
# 0    Educational attainment, Doctoral or equivalent...                 ..
# 1    Educational attainment, Doctoral or equivalent...                 ..
# 2    Educational attainment, Doctoral or equivalent...                 ..
# 3    Educational attainment, Doctoral or equivalent...                 ..
# 4    Educational attainment, Doctoral or equivalent...                 ..
# ..                                                 ...                ...
# 212  Educational attainment, Doctoral or equivalent...                 ..
# 213  Educational attainment, Doctoral or equivalent...  0.269989997148514
# 214  Educational attainment, Doctoral or equivalent...                 ..
# 215  Educational attainment, Doctoral or equivalent...                 ..
# 216  Educational attainment, Doctoral or equivalent...                 ..
#
# [217 rows x 7 columns]
