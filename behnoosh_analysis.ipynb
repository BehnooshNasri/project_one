# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = 'Gender Type and Education Level.csv'

initial_df = pd.read_csv(file_path)
initial_df
# Out:
#            Province/Territory  \
# 0   Newfoundland and Labrador
# 1   Newfoundland and Labrador
# 2   Newfoundland and Labrador
# 3   Newfoundland and Labrador
# 4   Newfoundland and Labrador
# ..                        ...
# 86                    Nunavut
# 87                    Nunavut
# 88                    Nunavut
# 89                    Nunavut
# 90                    Nunavut
#
#                                           Description   Total    Male  Female  \
# 0                                    Total population  510550  250075  260475
# 1   Total - Highest certificate, diploma or degree...  433960  211180  222775
# 2                                     Master's degree   17150    6990   10165
# 3                                    Earned doctorate    2610    1635     975
# 4   Total - Highest certificate, diploma or degree...  267785  129445  138340
# ..                                                ...     ...     ...     ...
# ...

# %%
print(initial_df.iloc[:, 0].unique())
# Out:
# ['Newfoundland and Labrador' 'Prince Edward Island' 'Nova Scotia'
#  'New Brunswick' 'Quebec' 'Ontario' 'Manitoba' 'Saskatchewan' 'Alberta'
#  'British Columbia' 'Yukon' 'Northwest Territories' 'Nunavut']

# %%
# Get unique values from the first column
unique_values = initial_df["Province/Territory"].unique()

# Create a dictionary to store DataFrames
dfs_by_province = {}

# Iterate through unique values and create DataFrames
for value in unique_values:
    # Filter the original DataFrame for the current value
    df_province = initial_df[initial_df["Province/Territory"] == value]
    
    # Store the DataFrame in the dictionary
    dfs_by_province[value] = df_province

# dfs_by_province['Newfoundland and Labrador']
dfs_by_province['Prince Edward Island']
# dfs_by_province['Nova Scotia']
# dfs_by_province['New Brunswick']
# dfs_by_province['Quebec']
# dfs_by_province['Ontario']
# dfs_by_province['Manitoba']
# dfs_by_province['Alberta']
# dfs_by_province['British Columbia']
# dfs_by_province['Yukon']
# dfs_by_province['Northwest Territories']
# dfs_by_province['Nunavut']
# Out:
#       Province/Territory                                        Description  \
# 7   Prince Edward Island                                   Total population
# 8   Prince Edward Island  Total - Highest certificate, diploma or degree...
# 9   Prince Edward Island                                    Master's degree
# 10  Prince Edward Island                                   Earned doctorate
# 11  Prince Edward Island  Total - Highest certificate, diploma or degree...
# 12  Prince Edward Island                                    Master's degree
# 13  Prince Edward Island                                   Earned doctorate
#
#      Total   Male  Female  % of Provincial Population  Male %  Female %
# 7   154330  75385   78945                       100.0   100.0     100.0
# 8   126895  61450   65445                       100.0   100.0     100.0
# 9     5930   2465    3465                         4.7     4.0       5.3
# 10     800    495     305                         0.6     0.8       0.5
# ...

# %%
print(dfs_by_province['Prince Edward Island']['Description'].unique())
# Out:
# ['Total population'
#  'Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25% sample data'
#  "      Master's degree" '      Earned doctorate'
#  'Total - Highest certificate, diploma or degree for the population aged 25 to 64 years in private households - 25% sample data']

# %%
pei = dfs_by_province['Prince Edward Island'][["Description", "Total", "Male", "Female", "% of Provincial Population", "Male %", "Female %"]]
pei.set_index("Description", inplace=True)
pei
# Out:
#                                           Description   Total   Male  Female  \
# 7                                    Total population  154330  75385   78945
# 8   Total - Highest certificate, diploma or degree...  126895  61450   65445
# 9                                     Master's degree    5930   2465    3465
# 10                                   Earned doctorate     800    495     305
# 11  Total - Highest certificate, diploma or degree...   77465  37375   40090
# 12                                    Master's degree    4685   1795    2890
# 13                                   Earned doctorate     595    350     245
#
#     % of Provincial Population  Male %  Female %
# 7                        100.0   100.0     100.0
# 8                        100.0   100.0     100.0
# 9                          4.7     4.0       5.3
# 10                         0.6     0.8       0.5
# 11                       100.0   100.0     100.0
# 12                         6.0     4.8       7.2
# ...

# %%
# #if it's better to flip rows and columns
#pei_transposed = pei.transpose()
# pei_transposed
# Out:
# Description                 Total population  \
# Total                               154330.0
# Male                                 75385.0
# Female                               78945.0
# % of Provincial Population             100.0
# Male %                                 100.0
# Female %                               100.0
#
# Description                 Total - Highest certificate, diploma or degree for the population aged 15 years and over in private households - 25% sample data  \
# Total                                                                126895.0
# Male                                                                  61450.0
# Female                                                                65445.0
# % of Provincial Population                                              100.0
# Male %                                                                  100.0
# Female %                                                                100.0
#
# ...

# %%
pei.describe()
# Out:
#                Total          Male        Female  % of Provincial Population  \
# count       7.000000      7.000000      7.000000                    7.000000
# mean    52957.142857  25616.428571  27340.714286                   44.585714
# std     66266.899031  32331.994566  33937.388235                   51.871457
# min       595.000000    350.000000    245.000000                    0.600000
# 25%      2742.500000   1145.000000   1597.500000                    2.750000
# 50%      5930.000000   2465.000000   3465.000000                    6.000000
# 75%    102180.000000  49412.500000  52767.500000                  100.000000
# max    154330.000000  75385.000000  78945.000000                  100.000000
#
#            Male %    Female %
# count    7.000000    7.000000
# mean    44.357143   44.800000
# std     52.069820   51.690199
# min      0.800000    0.500000
# 25%      2.450000    2.950000
# 50%      4.800000    7.200000
# 75%    100.000000  100.000000
# ...

# %%
# Bar plot for Total, Male, and Female
plt.figure(figsize=(12, 6))
pei[['Total', 'Male', 'Female']].plot(kind='bar', stacked=True)
plt.title('Population Distribution by Gender')
plt.xlabel('Education Level')
plt.ylabel('Population')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# Line plot for % of Provincial Population, Male %, and Female %
plt.figure(figsize=(12, 6))
pei[['% of Provincial Population', 'Male %', 'Female %']].plot(kind='line', marker='o')
plt.title('Percentage Distribution')
plt.xlabel('Education Level')
plt.ylabel('Percentage')
plt.xticks(rotation=45, ha='right')
plt.show()
