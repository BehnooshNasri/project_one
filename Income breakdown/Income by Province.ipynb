# %%
import pandas as pd
import numpy as np

# %%
csv = '9810007901-eng.csv'

main_df = pd.read_csv(csv, encoding='utf-8')
main_df
# Out:
#                                                Income  \
# 0                       Census family structure (7) 2
# 1                  Family size of census family (4) 3
# 2                  Ages of census family members (18)
# 3        Number of earners in the census family (5) 4
# 4                                          2021 Total
# 5                                        Under $5,000
# 6                                    $5,000 to $9,999
# 7                                  $10,000 to $14,999
# 8                                  $15,000 to $19,999
# 9                                  $20,000 to $24,999
# 10                                 $25,000 to $29,999
# 11                                 $30,000 to $34,999
# 12                                 $35,000 to $39,999
# 13                                 $40,000 to $44,999
# 14                                 $45,000 to $49,999
# 15                                 $50,000 to $59,999
# ...

# %%
preferred_rows = main_df.iloc[4:23]
preferred_rows
# Out:
#                                         Income Quebec i26 Ontario i56  \
# 4                                   2021 Total  2,323,410   3,969,670
# 5                                 Under $5,000      8,365      28,115
# 6                             $5,000 to $9,999      4,010      11,820
# 7                           $10,000 to $14,999      6,580      16,920
# 8                           $15,000 to $19,999     10,305      24,325
# 9                           $20,000 to $24,999     19,280      37,635
# 10                          $25,000 to $29,999     23,040      49,965
# 11                          $30,000 to $34,999     45,545      81,165
# 12                          $35,000 to $39,999     75,920     103,610
# 13                          $40,000 to $44,999     77,800     111,620
# 14                          $45,000 to $49,999     76,390     114,320
# 15                          $50,000 to $59,999    168,170     251,085
# ...
