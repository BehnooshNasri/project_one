# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# create folder for all outputs

output_folder = 'behnoosh_outputs'

# %%
file_path = ''

initial_df = pd.read_csv(file_path)
initial_df.head(20)
# Out:
#            Province/Territory                                     Description  \
# 0   Newfoundland and Labrador                                Total population
# 1   Newfoundland and Labrador  Total - Highest certificate, diploma or degree
# 2   Newfoundland and Labrador                                 Master's degree
# 3   Newfoundland and Labrador                                Earned doctorate
# 4        Prince Edward Island                                Total population
# 5        Prince Edward Island  Total - Highest certificate, diploma or degree
# 6        Prince Edward Island                                 Master's degree
# 7        Prince Edward Island                                Earned doctorate
# 8                 Nova Scotia                                Total population
# 9                 Nova Scotia  Total - Highest certificate, diploma or degree
# 10                Nova Scotia                                 Master's degree
# 11                Nova Scotia                                Earned doctorate
# 12              New Brunswick                                Total population
# 13              New Brunswick  Total - Highest certificate, diploma or degree
# 14              New Brunswick                                 Master's degree
# 15              New Brunswick                                Earned doctorate
# 16                     Quebec                                Total population
# 17                     Quebec  Total - Highest certificate, diploma or degree
# 18                     Quebec                                 Master's degree
# 19                     Quebec                                Earned doctorate
#
#       Total     Male   Female
# 0    510550   250075   260475
# 1    433960   211180   222775
# 2     17150     6990    10165
# 3      2610     1635      975
# 4    154330    75385    78945
# 5    126895    61450    65445
# 6      5930     2465     3465
# 7       800      495      305
# 8    969380   471730   497650
# 9    819315   395805   423510
# 10    43285    17675    25610
# 11     6745     3985     2760
# 12   775610   381455   394155
# 13   648245   316950   331300
# 14    23265    10540    12725
# 15     3705     2260     1445
# 16  8501835  4201960  4299870
# 17  6918730  3414515  3504210
# 18   360795   174150   186645
# 19    63270    36320    26955
